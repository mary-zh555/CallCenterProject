# %% [markdown]
# # EDA PROCESS

# %% [markdown]
# ## Preparing environment

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %reload_ext sql #TODO Delete

# %% [markdown]
# ### Getting data from .env file
#
# `If you want to repeat the process, please create you database and import csv file from raw_data folder`

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine

dotenv_path = ".env" #TODO Change to .env.example
load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL", " ")
print(DATABASE_URL)

engine = create_engine(DATABASE_URL)
# Out:
# postgresql://postgres:greenmars555@localhost/call_center_project

# %% [markdown]
# ### Checking the dataset

# %%
# %%sql
#
# SELECT *
# FROM Calls
# LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 5 rows affected.
# [('DKK-57076809-w-055481-fU                          ', 'Analise Gairdner                                  ', 'Neutral             ', 7, 'Billing Question    ', 'Detroit                                           ', 'Michigan            ', 'Call-Center         ', 'Within SLA          ', 17, 'Los Angeles/CA      ', datetime.date(2020, 10, 29)),
#  ('QGK-72219678-w-102139-KY                          ', 'Crichton Kidsley                                  ', 'Very Positive       ', None, 'Service Outage      ', 'Spartanburg                                       ', 'South Carolina      ', 'Chatbot             ', 'Within SLA          ', 23, 'Baltimore/MD        ', datetime.date(2020, 10, 5)),
#  ('GYJ-30025932-A-023015-LD                          ', 'Averill Brundrett                                 ', 'Negative            ', None, 'Billing Question    ', 'Gainesville                                       ', 'Florida             ', 'Call-Center         ', 'Above SLA           ', 45, 'Los Angeles/CA      ', datetime.date(2020, 10, 4)),
#  ('ZJI-96807559-i-620008-m7                          ', 'Noreen Lafflina                                   ', 'Very Negative       ', 1, 'Billing Question    ', 'Portland                                          ', 'Oregon              ', 'Chatbot             ', 'Within SLA          ', 12, 'Los Angeles/CA      ', datetime.date(2020, 10, 17)),
#  ('DDU-69451719-O-176482-Fm                          ', 'Toma Van der Beken                                ', 'Very Positive       ', None, 'Payments            ', 'Fort Wayne                                        ', 'Indiana             ', 'Call-Center         ', 'Within SLA          ', 23, 'Los Angeles/CA      ', datetime.date(2020, 10, 17))]

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Table Shape

# %%
# %%sql
#
# SELECT 'Rows' AS category, COUNT(*) AS count
#     FROM Calls
#
# UNION ALL
#
# SELECT 'Columns' AS category, COUNT(*) AS count
#     FROM information_schema.columns
#     WHERE table_name = 'calls';
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 2 rows affected.
# [('Rows', 32941), ('Columns', 12)]

# %% [markdown]
# ### Distinct values

# %% [markdown]
# 1. Only 4 call centers

# %%
# %%sql
#
# SELECT DISTINCT call_center FROM calls;
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 4 rows affected.
# [('Los Angeles/CA      ',),
#  ('Chicago/IL          ',),
#  ('Denver/CO           ',),
#  ('Baltimore/MD        ',)]

# %% [markdown]
# 2. There are 5 distinct sentiments

# %%
# %%sql
#
# SELECT DISTINCT sentiment FROM calls;
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 5 rows affected.
# [('Negative            ',),
#  ('Positive            ',),
#  ('Very Negative       ',),
#  ('Neutral             ',),
#  ('Very Positive       ',)]

# %% [markdown]
# 3. Only 3 different reasons

# %%
# %%sql
#
# SELECT DISTINCT reason FROM calls;
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 3 rows affected.
# [('Service Outage      ',),
#  ('Payments            ',),
#  ('Billing Question    ',)]

# %% [markdown]
# 4. And 4 distinct channels

# %%
# %%sql
#
# SELECT DISTINCT channel FROM calls;
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 4 rows affected.
# [('Chatbot             ',),
#  ('Web                 ',),
#  ('Email               ',),
#  ('Call-Center         ',)]

# %% [markdown]
# ### Percentages

# %% [markdown]
# `What are percentage of sentiments for each channel?`
#
# Result data for every channel is similar - mostly negative-neutral-very_negative

# %%
# %%sql
#
# SELECT
#     channel,
#     sentiment,
#     ROUND((COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (PARTITION BY channel)), 2) AS pct
# FROM
#     calls
# GROUP BY
#     channel, sentiment
# ORDER BY
#     channel, pct DESC;
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 20 rows affected.
# [('Call-Center         ', 'Negative            ', Decimal('33.56')),
#  ('Call-Center         ', 'Neutral             ', Decimal('26.18')),
#  ('Call-Center         ', 'Very Negative       ', Decimal('18.64')),
#  ('Call-Center         ', 'Positive            ', Decimal('11.70')),
#  ('Call-Center         ', 'Very Positive       ', Decimal('9.93')),
#  ('Chatbot             ', 'Negative            ', Decimal('33.15')),
#  ('Chatbot             ', 'Neutral             ', Decimal('26.66')),
#  ('Chatbot             ', 'Very Negative       ', Decimal('18.48')),
#  ('Chatbot             ', 'Positive            ', Decimal('11.91')),
#  ('Chatbot             ', 'Very Positive       ', Decimal('9.80')),
#  ('Email               ', 'Negative            ', Decimal('34.34')),
#  ('Email               ', 'Neutral             ', Decimal('26.71')),
#  ('Email               ', 'Very Negative       ', Decimal('17.99')),
#  ('Email               ', 'Positive            ', Decimal('11.55')),
#  ('Email               ', 'Very Positive       ', Decimal('9.41')),
#  ('Web                 ', 'Negative            ', Decimal('33.32')),
#  ('Web                 ', 'Neutral             ', Decimal('26.96')),
#  ('Web                 ', 'Very Negative       ', Decimal('17.84')),
#  ('Web                 ', 'Positive            ', Decimal('12.73')),
#  ('Web                 ', 'Very Positive       ', Decimal('9.15'))]

# %% [markdown]
# `Are there any uniqueness in channels based on the reason client contacted the center?`
#
# Yes, payments questions are only resolved by call_center channel. And Service Outage issues are not considered in call_center channel.

# %%
# %%sql
#
# SELECT
#     channel,
#     reason,
#     ROUND((COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (PARTITION BY channel)), 2) AS pct
# FROM
#     calls
# GROUP BY
#     channel, reason
# ORDER BY
#     channel, pct DESC;
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 8 rows affected.
# [('Call-Center         ', 'Billing Question    ', Decimal('55.36')),
#  ('Call-Center         ', 'Payments            ', Decimal('44.64')),
#  ('Chatbot             ', 'Billing Question    ', Decimal('71.48')),
#  ('Chatbot             ', 'Service Outage      ', Decimal('28.52')),
#  ('Email               ', 'Billing Question    ', Decimal('79.00')),
#  ('Email               ', 'Service Outage      ', Decimal('21.00')),
#  ('Web                 ', 'Billing Question    ', Decimal('87.74')),
#  ('Web                 ', 'Service Outage      ', Decimal('12.26'))]

# %% [markdown]
# `Which day of the week is the most busy with calls?`
#
# Friday, thursday the most busy; sunday is the least

# %%
# %%sql
#
# select to_char(call_date, 'Day' ) as day_of_call,
# 	round((count(*)*100.0)/(select count(*) from calls),2) as percentage
# from calls
# group by 1
# order by 2 desc;
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 7 rows affected.
# [('Friday   ', Decimal('16.91')),
#  ('Thursday ', Decimal('16.64')),
#  ('Wednesday', Decimal('13.51')),
#  ('Tuesday  ', Decimal('13.38')),
#  ('Saturday ', Decimal('13.37')),
#  ('Monday   ', Decimal('13.16')),
#  ('Sunday   ', Decimal('13.04'))]

# %% [markdown]
# ### AGGREGATIONS:

# %% [markdown]
# 1. SCORE

# %%
# %%sql
#
# select min(csat_score) as min_score,
#     max(csat_score) as max_score,
#     round(avg(csat_score),1) as avg_score
# from calls
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 1 rows affected.
# [(1, 10, Decimal('5.5'))]

# %%
# %%sql
#
# select min(call_date) as earliest_date,
#     max(call_date) as most_recent_date
# from calls
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 1 rows affected.
# [(datetime.date(2020, 10, 1), datetime.date(2020, 10, 31))]

# %%
# %%sql
#
# select min(duration_minutes) as min_call_duration,
#     max(duration_minutes) as max_call_duration,
#     round(avg(duration_minutes),1) as avg_call_duration
# from calls
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 1 rows affected.
# [(5, 45, Decimal('25.0'))]

# %%
# %%sql
#
# select call_center, response_time, count(*) as count
# from calls
# group by call_center, response_time
# order by call_center asc, count desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 12 rows affected.
# [('Baltimore/MD        ', 'Within SLA          ', 6855),
#  ('Baltimore/MD        ', 'Below SLA           ', 2768),
#  ('Baltimore/MD        ', 'Above SLA           ', 1389),
#  ('Chicago/IL          ', 'Within SLA          ', 3361),
#  ('Chicago/IL          ', 'Below SLA           ', 1361),
#  ('Chicago/IL          ', 'Above SLA           ', 697),
#  ('Denver/CO           ', 'Within SLA          ', 1741),
#  ('Denver/CO           ', 'Below SLA           ', 692),
#  ('Denver/CO           ', 'Above SLA           ', 343),
#  ('Los Angeles/CA      ', 'Within SLA          ', 8668),
#  ('Los Angeles/CA      ', 'Below SLA           ', 3327),
#  ('Los Angeles/CA      ', 'Above SLA           ', 1739)]

# %%
# %%sql
#
# select call_center, avg(duration_minutes) as avg_duration
# from calls
# group by call_center
# order by avg_duration desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 4 rows affected.
# [('Chicago/IL          ', Decimal('25.0625576674663222')),
#  ('Los Angeles/CA      ', Decimal('25.0532255715741954')),
#  ('Denver/CO           ', Decimal('25.0165706051873199')),
#  ('Baltimore/MD        ', Decimal('24.9619505993461678'))]

# %%
# %%sql
#
# select channel, avg(duration_minutes) as avg_duration
# from calls
# group by channel
# order by avg_duration desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 4 rows affected.
# [('Email               ', Decimal('25.0987951807228916')),
#  ('Call-Center         ', Decimal('25.0461509540370336')),
#  ('Web                 ', Decimal('25.0223540145985401')),
#  ('Chatbot             ', Decimal('24.9177567829457364'))]

# %%
# %%sql
#
# select state, round(avg(duration_minutes), 2) as avg_duration
# from calls
# group by state
# order by avg_duration desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 51 rows affected.
# [('Rhode Island        ', Decimal('27.66')),
#  ('Delaware            ', Decimal('26.59')),
#  ('Hawaii              ', Decimal('26.21')),
#  ('Montana             ', Decimal('26.09')),
#  ('South Dakota        ', Decimal('26.08')),
#  ('Idaho               ', Decimal('26.07')),
#  ('Illinois            ', Decimal('26.04')),
#  ('Kansas              ', Decimal('25.88')),
#  ('Minnesota           ', Decimal('25.84')),
#  ('Michigan            ', Decimal('25.73')),
#  ('Connecticut         ', Decimal('25.62')),
#  ('Wisconsin           ', Decimal('25.52')),
#  ('Pennsylvania        ', Decimal('25.47')),
#  ('Iowa                ', Decimal('25.39')),
#  ('Kentucky            ', Decimal('25.36')),
#  ('West Virginia       ', Decimal('25.20')),
#  ('Maryland            ', Decimal('25.19')),
#  ('Louisiana           ', Decimal('25.19')),
#  ('Arkansas            ', Decimal('25.16')),
#  ('Florida             ', Decimal('25.10')),
#  ('District of Columbia', Decimal('25.10')),
#  ('California          ', Decimal('25.06')),
#  ('Oregon              ', Decimal('25.06')),
#  ('Texas               ', Decimal('25.06')),
#  ('Indiana             ', Decimal('24.98')),
#  ('Massachusetts       ', Decimal('24.97')),
#  ('Ohio                ', Decimal('24.96')),
#  ('Nevada              ', Decimal('24.96')),
#  ('New York            ', Decimal('24.93')),
#  ('Alabama             ', Decimal('24.92')),
#  ('Tennessee           ', Decimal('24.91')),
#  ('Virginia            ', Decimal('24.88')),
#  ('New Mexico          ', Decimal('24.80')),
#  ('North Carolina      ', Decimal('24.73')),
#  ('Nebraska            ', Decimal('24.71')),
#  ('Mississippi         ', Decimal('24.62')),
#  ('Georgia             ', Decimal('24.61')),
#  ('Oklahoma            ', Decimal('24.60')),
#  ('New Jersey          ', Decimal('24.52')),
#  ('Vermont             ', Decimal('24.36')),
#  ('Arizona             ', Decimal('24.33')),
#  ('North Dakota        ', Decimal('24.32')),
#  ('Washington          ', Decimal('24.28')),
#  ('Utah                ', Decimal('24.24')),
#  ('South Carolina      ', Decimal('24.21')),
#  ('Colorado            ', Decimal('24.07')),
#  ('Missouri            ', Decimal('24.03')),
#  ('Wyoming             ', Decimal('24.00')),
#  ('Alaska              ', Decimal('23.49')),
#  ('New Hampshire       ', Decimal('22.63')),
#  ('Maine               ', Decimal('22.38'))]

# %%
# %%sql
#
# select state, count(*) as count
# from calls
# group by state
# order by count desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 51 rows affected.
# [('California          ', 3631),
#  ('Texas               ', 3572),
#  ('Florida             ', 2834),
#  ('New York            ', 1786),
#  ('Virginia            ', 1164),
#  ('Ohio                ', 1160),
#  ('District of Columbia', 1110),
#  ('Pennsylvania        ', 1017),
#  ('Georgia             ', 926),
#  ('Illinois            ', 848),
#  ('North Carolina      ', 765),
#  ('Colorado            ', 742),
#  ('Alabama             ', 738),
#  ('Arizona             ', 737),
#  ('Indiana             ', 736),
#  ('Minnesota           ', 712),
#  ('Missouri            ', 682),
#  ('Tennessee           ', 664),
#  ('Washington          ', 663),
#  ('Louisiana           ', 627),
#  ('Michigan            ', 612),
#  ('Oklahoma            ', 538),
#  ('Massachusetts       ', 493),
#  ('Kansas              ', 467),
#  ('Nevada              ', 459),
#  ('Maryland            ', 415),
#  ('Kentucky            ', 411),
#  ('Connecticut         ', 408),
#  ('Iowa                ', 366),
#  ('Wisconsin           ', 342),
#  ('New Jersey          ', 317),
#  ('South Carolina      ', 315),
#  ('West Virginia       ', 301),
#  ('Utah                ', 298),
#  ('Oregon              ', 261),
#  ('Nebraska            ', 243),
#  ('New Mexico          ', 212),
#  ('Arkansas            ', 204),
#  ('Mississippi         ', 178),
#  ('Idaho               ', 174),
#  ('Hawaii              ', 149),
#  ('Alaska              ', 146),
#  ('Delaware            ', 128),
#  ('Montana             ', 94),
#  ('South Dakota        ', 93),
#  ('North Dakota        ', 76),
#  ('New Hampshire       ', 51),
#  ('Rhode Island        ', 35),
#  ('Maine               ', 16),
#  ('Vermont             ', 14),
#  ('Wyoming             ', 11)]

# %%
# %%sql
#
# select state, reason, count(*) as count
# from calls
# group by state, reason
# order by count, reason, count desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 153 rows affected.
# [('Vermont             ', 'Service Outage      ', 1),
#  ('Wyoming             ', 'Service Outage      ', 1),
#  ('Maine               ', 'Service Outage      ', 1),
#  ('Rhode Island        ', 'Service Outage      ', 2),
#  ('Vermont             ', 'Payments            ', 3),
#  ('Maine               ', 'Payments            ', 3),
#  ('Wyoming             ', 'Payments            ', 4),
#  ('New Hampshire       ', 'Payments            ', 5),
#  ('Wyoming             ', 'Billing Question    ', 6),
#  ('Rhode Island        ', 'Payments            ', 6),
#  ('North Dakota        ', 'Payments            ', 7),
#  ('Montana             ', 'Payments            ', 9),
#  ('North Dakota        ', 'Service Outage      ', 9),
#  ('New Hampshire       ', 'Service Outage      ', 9),
#  ('Vermont             ', 'Billing Question    ', 10),
#  ('Maine               ', 'Billing Question    ', 12),
#  ('Montana             ', 'Service Outage      ', 12),
#  ('South Dakota        ', 'Service Outage      ', 14),
#  ('Mississippi         ', 'Service Outage      ', 16),
#  ('Delaware            ', 'Service Outage      ', 16),
#  ('South Dakota        ', 'Payments            ', 18),
#  ('Hawaii              ', 'Service Outage      ', 19),
#  ('Idaho               ', 'Service Outage      ', 21),
#  ('Delaware            ', 'Payments            ', 22),
#  ('Hawaii              ', 'Payments            ', 23),
#  ('Arkansas            ', 'Service Outage      ', 23),
#  ('Alaska              ', 'Payments            ', 25),
#  ('New Mexico          ', 'Payments            ', 25),
#  ('Rhode Island        ', 'Billing Question    ', 27),
#  ('Nebraska            ', 'Service Outage      ', 28),
#  ('Alaska              ', 'Service Outage      ', 28),
#  ('Arkansas            ', 'Payments            ', 29),
#  ('Idaho               ', 'Payments            ', 29),
#  ('New Mexico          ', 'Service Outage      ', 29),
#  ('Mississippi         ', 'Payments            ', 33),
#  ('Oregon              ', 'Payments            ', 34),
#  ('New Hampshire       ', 'Billing Question    ', 37),
#  ('Nebraska            ', 'Payments            ', 40),
#  ('South Carolina      ', 'Payments            ', 40),
#  ('Oregon              ', 'Service Outage      ', 41),
#  ('Wisconsin           ', 'Service Outage      ', 43),
#  ('West Virginia       ', 'Payments            ', 45),
#  ('Maryland            ', 'Payments            ', 45),
#  ('Utah                ', 'Payments            ', 46),
#  ('Nevada              ', 'Payments            ', 46),
#  ('Utah                ', 'Service Outage      ', 47),
#  ('New Jersey          ', 'Payments            ', 49),
#  ('Wisconsin           ', 'Payments            ', 49),
#  ('South Carolina      ', 'Service Outage      ', 50),
#  ('Kentucky            ', 'Service Outage      ', 50),
#  ('Iowa                ', 'Service Outage      ', 50),
#  ('Iowa                ', 'Payments            ', 54),
#  ('New Jersey          ', 'Service Outage      ', 57),
#  ('West Virginia       ', 'Service Outage      ', 59),
#  ('North Dakota        ', 'Billing Question    ', 60),
#  ('South Dakota        ', 'Billing Question    ', 61),
#  ('Connecticut         ', 'Service Outage      ', 64),
#  ('Kentucky            ', 'Payments            ', 65),
#  ('Michigan            ', 'Payments            ', 66),
#  ('Massachusetts       ', 'Payments            ', 67),
#  ('Maryland            ', 'Service Outage      ', 67),
#  ('Kansas              ', 'Payments            ', 68),
#  ('Kansas              ', 'Service Outage      ', 68),
#  ('Connecticut         ', 'Payments            ', 69),
#  ('Massachusetts       ', 'Service Outage      ', 70),
#  ('Nevada              ', 'Service Outage      ', 70),
#  ('Montana             ', 'Billing Question    ', 73),
#  ('Oklahoma            ', 'Payments            ', 77),
#  ('Oklahoma            ', 'Service Outage      ', 79),
#  ('Louisiana           ', 'Payments            ', 83),
#  ('Washington          ', 'Payments            ', 83),
#  ('Louisiana           ', 'Service Outage      ', 84),
#  ('Delaware            ', 'Billing Question    ', 90),
#  ('Michigan            ', 'Service Outage      ', 91),
#  ('Alaska              ', 'Billing Question    ', 93),
#  ('Tennessee           ', 'Payments            ', 93),
#  ('Missouri            ', 'Service Outage      ', 93),
#  ('Tennessee           ', 'Service Outage      ', 93),
#  ('Colorado            ', 'Service Outage      ', 94),
#  ('North Carolina      ', 'Service Outage      ', 95),
#  ('Alabama             ', 'Service Outage      ', 95),
#  ('Missouri            ', 'Payments            ', 97),
#  ('Washington          ', 'Service Outage      ', 100),
#  ('Minnesota           ', 'Payments            ', 104),
#  ('Indiana             ', 'Service Outage      ', 104),
#  ('Alabama             ', 'Payments            ', 105),
#  ('Minnesota           ', 'Service Outage      ', 106),
#  ('Hawaii              ', 'Billing Question    ', 107),
#  ('North Carolina      ', 'Payments            ', 111),
#  ('Arizona             ', 'Service Outage      ', 111),
#  ('Indiana             ', 'Payments            ', 115),
#  ('Arizona             ', 'Payments            ', 119),
#  ('Idaho               ', 'Billing Question    ', 124),
#  ('Mississippi         ', 'Billing Question    ', 129),
#  ('Illinois            ', 'Service Outage      ', 129),
#  ('Georgia             ', 'Payments            ', 132),
#  ('Colorado            ', 'Payments            ', 132),
#  ('District of Columbia', 'Service Outage      ', 140),
#  ('Georgia             ', 'Service Outage      ', 141),
#  ('Virginia            ', 'Payments            ', 150),
#  ('Pennsylvania        ', 'Payments            ', 150),
#  ('Illinois            ', 'Payments            ', 151),
#  ('Arkansas            ', 'Billing Question    ', 152),
#  ('New Mexico          ', 'Billing Question    ', 158),
#  ('Virginia            ', 'Service Outage      ', 160),
#  ('District of Columbia', 'Payments            ', 164),
#  ('Ohio                ', 'Payments            ', 166),
#  ('Pennsylvania        ', 'Service Outage      ', 166),
#  ('Nebraska            ', 'Billing Question    ', 175),
#  ('Ohio                ', 'Service Outage      ', 175),
#  ('Oregon              ', 'Billing Question    ', 186),
#  ('West Virginia       ', 'Billing Question    ', 197),
#  ('Utah                ', 'Billing Question    ', 205),
#  ('New Jersey          ', 'Billing Question    ', 211),
#  ('South Carolina      ', 'Billing Question    ', 225),
#  ('Wisconsin           ', 'Billing Question    ', 250),
#  ('New York            ', 'Service Outage      ', 252),
#  ('Iowa                ', 'Billing Question    ', 262),
#  ('New York            ', 'Payments            ', 267),
#  ('Connecticut         ', 'Billing Question    ', 275),
#  ('Kentucky            ', 'Billing Question    ', 296),
#  ('Maryland            ', 'Billing Question    ', 303),
#  ('Kansas              ', 'Billing Question    ', 331),
#  ('Nevada              ', 'Billing Question    ', 343),
#  ('Massachusetts       ', 'Billing Question    ', 356),
#  ('Oklahoma            ', 'Billing Question    ', 382),
#  ('Florida             ', 'Service Outage      ', 401),
#  ('Florida             ', 'Payments            ', 418),
#  ('Michigan            ', 'Billing Question    ', 455),
#  ('Louisiana           ', 'Billing Question    ', 460),
#  ('Tennessee           ', 'Billing Question    ', 478),
#  ('Washington          ', 'Billing Question    ', 480),
#  ('Missouri            ', 'Billing Question    ', 492),
#  ('California          ', 'Payments            ', 501),
#  ('Minnesota           ', 'Billing Question    ', 502),
#  ('Arizona             ', 'Billing Question    ', 507),
#  ('Texas               ', 'Payments            ', 507),
#  ('Texas               ', 'Service Outage      ', 514),
#  ('Colorado            ', 'Billing Question    ', 516),
#  ('Indiana             ', 'Billing Question    ', 517),
#  ('Alabama             ', 'Billing Question    ', 538),
#  ('California          ', 'Service Outage      ', 542),
#  ('North Carolina      ', 'Billing Question    ', 559),
#  ('Illinois            ', 'Billing Question    ', 568),
#  ('Georgia             ', 'Billing Question    ', 653),
#  ('Pennsylvania        ', 'Billing Question    ', 701),
#  ('District of Columbia', 'Billing Question    ', 806),
#  ('Ohio                ', 'Billing Question    ', 819),
#  ('Virginia            ', 'Billing Question    ', 854),
#  ('New York            ', 'Billing Question    ', 1267),
#  ('Florida             ', 'Billing Question    ', 2015),
#  ('Texas               ', 'Billing Question    ', 2551),
#  ('California          ', 'Billing Question    ', 2588)]

# %%
# %%sql
#
# select state, sentiment, count(*) as count
# from calls
# group by state, sentiment
# order by count, count desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 250 rows affected.
# [('Rhode Island        ', 'Very Positive       ', 1),
#  ('Maine               ', 'Very Positive       ', 1),
#  ('Vermont             ', 'Very Negative       ', 2),
#  ('Wyoming             ', 'Neutral             ', 3),
#  ('Maine               ', 'Very Negative       ', 3),
#  ('New Hampshire       ', 'Very Positive       ', 3),
#  ('Vermont             ', 'Positive            ', 3),
#  ('Vermont             ', 'Negative            ', 4),
#  ('Maine               ', 'Negative            ', 4),
#  ('North Dakota        ', 'Very Positive       ', 4),
#  ('New Hampshire       ', 'Positive            ', 4),
#  ('Rhode Island        ', 'Very Negative       ', 5),
#  ('Rhode Island        ', 'Positive            ', 5),
#  ('Vermont             ', 'Neutral             ', 5),
#  ('Montana             ', 'Very Positive       ', 6),
#  ('South Dakota        ', 'Very Positive       ', 6),
#  ('New Hampshire       ', 'Very Negative       ', 7),
#  ('Maine               ', 'Neutral             ', 8),
#  ('Wyoming             ', 'Negative            ', 8),
#  ('North Dakota        ', 'Very Negative       ', 9),
#  ('Rhode Island        ', 'Negative            ', 10),
#  ('North Dakota        ', 'Positive            ', 12),
#  ('South Dakota        ', 'Positive            ', 13),
#  ('Montana             ', 'Positive            ', 14),
#  ('Delaware            ', 'Positive            ', 14),
#  ('Hawaii              ', 'Very Positive       ', 14),
#  ('South Dakota        ', 'Very Negative       ', 14),
#  ('Rhode Island        ', 'Neutral             ', 14),
#  ('Delaware            ', 'Very Positive       ', 15),
#  ('Alaska              ', 'Very Positive       ', 16),
#  ('Hawaii              ', 'Positive            ', 17),
#  ('North Dakota        ', 'Neutral             ', 17),
#  ('New Hampshire       ', 'Negative            ', 18),
#  ('New Hampshire       ', 'Neutral             ', 19),
#  ('Mississippi         ', 'Very Positive       ', 19),
#  ('Nebraska            ', 'Very Positive       ', 19),
#  ('Arkansas            ', 'Positive            ', 20),
#  ('Idaho               ', 'Very Positive       ', 20),
#  ('Oregon              ', 'Very Positive       ', 20),
#  ('Hawaii              ', 'Very Negative       ', 20),
#  ('Arkansas            ', 'Very Positive       ', 22),
#  ('Montana             ', 'Very Negative       ', 22),
#  ('Nebraska            ', 'Positive            ', 23),
#  ('Idaho               ', 'Positive            ', 23),
#  ('New Mexico          ', 'Very Positive       ', 23),
#  ('South Dakota        ', 'Neutral             ', 24),
#  ('Montana             ', 'Neutral             ', 24),
#  ('Alaska              ', 'Positive            ', 25),
#  ('Delaware            ', 'Neutral             ', 26),
#  ('New Mexico          ', 'Positive            ', 26),
#  ('Delaware            ', 'Very Negative       ', 27),
#  ('West Virginia       ', 'Very Positive       ', 27),
#  ('Utah                ', 'Very Positive       ', 28),
#  ('Montana             ', 'Negative            ', 28),
#  ('South Carolina      ', 'Positive            ', 28),
#  ('Mississippi         ', 'Very Negative       ', 28),
#  ('Alaska              ', 'Very Negative       ', 28),
#  ('Idaho               ', 'Very Negative       ', 29),
#  ('Mississippi         ', 'Positive            ', 29),
#  ('South Carolina      ', 'Very Positive       ', 31),
#  ('Wisconsin           ', 'Very Positive       ', 31),
#  ('Oregon              ', 'Positive            ', 32),
#  ('Alaska              ', 'Neutral             ', 32),
#  ('North Dakota        ', 'Negative            ', 34),
#  ('Iowa                ', 'Very Positive       ', 36),
#  ('New Jersey          ', 'Very Positive       ', 36),
#  ('South Dakota        ', 'Negative            ', 36),
#  ('Arkansas            ', 'Very Negative       ', 39),
#  ('West Virginia       ', 'Positive            ', 39),
#  ('Mississippi         ', 'Neutral             ', 40),
#  ('Maryland            ', 'Very Positive       ', 40),
#  ('Connecticut         ', 'Very Positive       ', 41),
#  ('Wisconsin           ', 'Positive            ', 41),
#  ('Maryland            ', 'Positive            ', 42),
#  ('Kentucky            ', 'Very Positive       ', 43),
#  ('New Jersey          ', 'Positive            ', 44),
#  ('Alaska              ', 'Negative            ', 45),
#  ('Utah                ', 'Positive            ', 45),
#  ('Kentucky            ', 'Positive            ', 45),
#  ('Delaware            ', 'Negative            ', 46),
#  ('Idaho               ', 'Neutral             ', 47),
#  ('New Mexico          ', 'Very Negative       ', 47),
#  ('Hawaii              ', 'Negative            ', 48),
#  ('Nevada              ', 'Very Positive       ', 48),
#  ('Kansas              ', 'Very Positive       ', 49),
#  ('Iowa                ', 'Positive            ', 49),
#  ('Hawaii              ', 'Neutral             ', 50),
#  ('Arkansas            ', 'Neutral             ', 50),
#  ('Oklahoma            ', 'Very Positive       ', 50),
#  ('Nevada              ', 'Positive            ', 50),
#  ('Nebraska            ', 'Very Negative       ', 51),
#  ('West Virginia       ', 'Very Negative       ', 52),
#  ('Kansas              ', 'Positive            ', 53),
#  ('New Mexico          ', 'Neutral             ', 54),
#  ('Washington          ', 'Very Positive       ', 54),
#  ('Oregon              ', 'Very Negative       ', 54),
#  ('Utah                ', 'Very Negative       ', 55),
#  ('Louisiana           ', 'Very Positive       ', 55),
#  ('Idaho               ', 'Negative            ', 55),
#  ('Michigan            ', 'Very Positive       ', 55),
#  ('Massachusetts       ', 'Very Positive       ', 56),
#  ('Connecticut         ', 'Positive            ', 56),
#  ('Minnesota           ', 'Very Positive       ', 57),
#  ('New Jersey          ', 'Very Negative       ', 59),
#  ('Tennessee           ', 'Very Positive       ', 60),
#  ('New Mexico          ', 'Negative            ', 62),
#  ('Mississippi         ', 'Negative            ', 62),
#  ('Nebraska            ', 'Neutral             ', 62),
#  ('Colorado            ', 'Very Positive       ', 65),
#  ('Missouri            ', 'Very Positive       ', 66),
#  ('Tennessee           ', 'Positive            ', 68),
#  ('Connecticut         ', 'Very Negative       ', 68),
#  ('Wisconsin           ', 'Very Negative       ', 69),
#  ('Iowa                ', 'Very Negative       ', 70),
#  ('Alabama             ', 'Very Positive       ', 70),
#  ('Massachusetts       ', 'Positive            ', 71),
#  ('Utah                ', 'Neutral             ', 71),
#  ('Arkansas            ', 'Negative            ', 73),
#  ('Arizona             ', 'Very Positive       ', 73),
#  ('South Carolina      ', 'Very Negative       ', 73),
#  ('Alabama             ', 'Positive            ', 74),
#  ('Oklahoma            ', 'Positive            ', 74),
#  ('North Carolina      ', 'Very Positive       ', 76),
#  ('Oklahoma            ', 'Very Negative       ', 76),
#  ('Oregon              ', 'Neutral             ', 76),
#  ('Indiana             ', 'Very Positive       ', 77),
#  ('New Jersey          ', 'Neutral             ', 79),
#  ('Oregon              ', 'Negative            ', 79),
#  ('Missouri            ', 'Positive            ', 80),
#  ('Michigan            ', 'Positive            ', 81),
#  ('Indiana             ', 'Positive            ', 82),
#  ('Wisconsin           ', 'Neutral             ', 82),
#  ('Maryland            ', 'Very Negative       ', 83),
#  ('Louisiana           ', 'Positive            ', 84),
#  ('Kansas              ', 'Very Negative       ', 84),
#  ('Massachusetts       ', 'Very Negative       ', 85),
#  ('Colorado            ', 'Positive            ', 85),
#  ('West Virginia       ', 'Negative            ', 85),
#  ('South Carolina      ', 'Neutral             ', 88),
#  ('Nebraska            ', 'Negative            ', 88),
#  ('North Carolina      ', 'Positive            ', 89),
#  ('Kentucky            ', 'Very Negative       ', 93),
#  ('Illinois            ', 'Positive            ', 94),
#  ('Minnesota           ', 'Positive            ', 94),
#  ('Arizona             ', 'Positive            ', 94),
#  ('Georgia             ', 'Very Positive       ', 95),
#  ('South Carolina      ', 'Negative            ', 95),
#  ('Iowa                ', 'Neutral             ', 97),
#  ('Washington          ', 'Positive            ', 97),
#  ('Illinois            ', 'Very Positive       ', 97),
#  ('West Virginia       ', 'Neutral             ', 98),
#  ('New Jersey          ', 'Negative            ', 99),
#  ('Utah                ', 'Negative            ', 99),
#  ('Pennsylvania        ', 'Very Positive       ', 101),
#  ('District of Columbia', 'Very Positive       ', 102),
#  ('Nevada              ', 'Very Negative       ', 105),
#  ('Connecticut         ', 'Neutral             ', 105),
#  ('Minnesota           ', 'Very Negative       ', 106),
#  ('Washington          ', 'Very Negative       ', 106),
#  ('Virginia            ', 'Very Positive       ', 109),
#  ('Pennsylvania        ', 'Positive            ', 111),
#  ('Tennessee           ', 'Very Negative       ', 111),
#  ('Ohio                ', 'Very Positive       ', 111),
#  ('Kentucky            ', 'Neutral             ', 112),
#  ('Georgia             ', 'Positive            ', 113),
#  ('Iowa                ', 'Negative            ', 114),
#  ('Maryland            ', 'Neutral             ', 114),
#  ('Louisiana           ', 'Very Negative       ', 115),
#  ('Kentucky            ', 'Negative            ', 118),
#  ('Wisconsin           ', 'Negative            ', 119),
#  ('Indiana             ', 'Very Negative       ', 123),
#  ('Nevada              ', 'Neutral             ', 125),
#  ('Michigan            ', 'Very Negative       ', 129),
#  ('Alabama             ', 'Very Negative       ', 129),
#  ('Arizona             ', 'Very Negative       ', 131),
#  ('Nevada              ', 'Negative            ', 131),
#  ('Kansas              ', 'Negative            ', 132),
#  ('Missouri            ', 'Very Negative       ', 132),
#  ('District of Columbia', 'Positive            ', 133),
#  ('Massachusetts       ', 'Neutral             ', 135),
#  ('Virginia            ', 'Positive            ', 135),
#  ('Maryland            ', 'Negative            ', 136),
#  ('Connecticut         ', 'Negative            ', 138),
#  ('Ohio                ', 'Positive            ', 140),
#  ('North Carolina      ', 'Very Negative       ', 143),
#  ('Michigan            ', 'Neutral             ', 144),
#  ('Massachusetts       ', 'Negative            ', 146),
#  ('Oklahoma            ', 'Neutral             ', 146),
#  ('Illinois            ', 'Very Negative       ', 148),
#  ('Kansas              ', 'Neutral             ', 149),
#  ('Colorado            ', 'Very Negative       ', 158),
#  ('Washington          ', 'Neutral             ', 161),
#  ('New York            ', 'Very Positive       ', 169),
#  ('Louisiana           ', 'Neutral             ', 174),
#  ('Georgia             ', 'Very Negative       ', 176),
#  ('Colorado            ', 'Neutral             ', 181),
#  ('Missouri            ', 'Neutral             ', 182),
#  ('Pennsylvania        ', 'Very Negative       ', 186),
#  ('Minnesota           ', 'Neutral             ', 186),
#  ('Tennessee           ', 'Neutral             ', 190),
#  ('District of Columbia', 'Very Negative       ', 190),
#  ('North Carolina      ', 'Neutral             ', 190),
#  ('New York            ', 'Positive            ', 190),
#  ('Oklahoma            ', 'Negative            ', 192),
#  ('Ohio                ', 'Very Negative       ', 197),
#  ('Indiana             ', 'Neutral             ', 198),
#  ('Louisiana           ', 'Negative            ', 199),
#  ('Alabama             ', 'Neutral             ', 200),
#  ('Michigan            ', 'Negative            ', 203),
#  ('Arizona             ', 'Neutral             ', 204),
#  ('Missouri            ', 'Negative            ', 222),
#  ('Illinois            ', 'Neutral             ', 223),
#  ('Tennessee           ', 'Negative            ', 235),
#  ('Arizona             ', 'Negative            ', 235),
#  ('Georgia             ', 'Neutral             ', 238),
#  ('Virginia            ', 'Very Negative       ', 240),
#  ('Washington          ', 'Negative            ', 245),
#  ('Colorado            ', 'Negative            ', 253),
#  ('Indiana             ', 'Negative            ', 256),
#  ('Alabama             ', 'Negative            ', 265),
#  ('North Carolina      ', 'Negative            ', 267),
#  ('Minnesota           ', 'Negative            ', 269),
#  ('Florida             ', 'Very Positive       ', 275),
#  ('Illinois            ', 'Negative            ', 286),
#  ('Pennsylvania        ', 'Neutral             ', 289),
#  ('District of Columbia', 'Neutral             ', 290),
#  ('Georgia             ', 'Negative            ', 304),
#  ('Ohio                ', 'Neutral             ', 304),
#  ('Virginia            ', 'Neutral             ', 314),
#  ('Pennsylvania        ', 'Negative            ', 330),
#  ('Texas               ', 'Very Positive       ', 337),
#  ('New York            ', 'Very Negative       ', 339),
#  ('Florida             ', 'Positive            ', 348),
#  ('California          ', 'Very Positive       ', 361),
#  ('Virginia            ', 'Negative            ', 366),
#  ('District of Columbia', 'Negative            ', 395),
#  ('Ohio                ', 'Negative            ', 408),
#  ('Texas               ', 'Positive            ', 417),
#  ('California          ', 'Positive            ', 422),
#  ('New York            ', 'Neutral             ', 487),
#  ('Florida             ', 'Very Negative       ', 541),
#  ('New York            ', 'Negative            ', 601),
#  ('California          ', 'Very Negative       ', 630),
#  ('Texas               ', 'Very Negative       ', 639),
#  ('Florida             ', 'Neutral             ', 750),
#  ('Florida             ', 'Negative            ', 920),
#  ('Texas               ', 'Neutral             ', 934),
#  ('California          ', 'Neutral             ', 963),
#  ('Texas               ', 'Negative            ', 1245),
#  ('California          ', 'Negative            ', 1255)]

# %%
# %%sql
#
# select state, round(avg(csat_score),2) as avg_score
# from calls
# group by state
# order by avg_score desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 51 rows affected.
# [('Vermont             ', Decimal('6.50')),
#  ('North Dakota        ', Decimal('6.37')),
#  ('Wyoming             ', Decimal('6.00')),
#  ('Massachusetts       ', Decimal('5.91')),
#  ('Rhode Island        ', Decimal('5.89')),
#  ('Hawaii              ', Decimal('5.87')),
#  ('Mississippi         ', Decimal('5.83')),
#  ('Idaho               ', Decimal('5.82')),
#  ('Washington          ', Decimal('5.76')),
#  ('Louisiana           ', Decimal('5.74')),
#  ('Illinois            ', Decimal('5.71')),
#  ('Georgia             ', Decimal('5.69')),
#  ('Utah                ', Decimal('5.67')),
#  ('Pennsylvania        ', Decimal('5.67')),
#  ('West Virginia       ', Decimal('5.63')),
#  ('Ohio                ', Decimal('5.63')),
#  ('Florida             ', Decimal('5.62')),
#  ('Oklahoma            ', Decimal('5.60')),
#  ('Tennessee           ', Decimal('5.60')),
#  ('Texas               ', Decimal('5.59')),
#  ('Kansas              ', Decimal('5.57')),
#  ('California          ', Decimal('5.57')),
#  ('Missouri            ', Decimal('5.57')),
#  ('Colorado            ', Decimal('5.57')),
#  ('Alaska              ', Decimal('5.56')),
#  ('Arizona             ', Decimal('5.55')),
#  ('Oregon              ', Decimal('5.55')),
#  ('New Jersey          ', Decimal('5.54')),
#  ('Wisconsin           ', Decimal('5.52')),
#  ('Montana             ', Decimal('5.52')),
#  ('Alabama             ', Decimal('5.51')),
#  ('Indiana             ', Decimal('5.51')),
#  ('South Dakota        ', Decimal('5.51')),
#  ('District of Columbia', Decimal('5.47')),
#  ('Kentucky            ', Decimal('5.47')),
#  ('North Carolina      ', Decimal('5.47')),
#  ('Connecticut         ', Decimal('5.45')),
#  ('Minnesota           ', Decimal('5.44')),
#  ('Michigan            ', Decimal('5.44')),
#  ('Iowa                ', Decimal('5.43')),
#  ('Virginia            ', Decimal('5.38')),
#  ('New York            ', Decimal('5.38')),
#  ('New Mexico          ', Decimal('5.36')),
#  ('Nevada              ', Decimal('5.26')),
#  ('Maryland            ', Decimal('5.23')),
#  ('South Carolina      ', Decimal('5.19')),
#  ('Arkansas            ', Decimal('5.18')),
#  ('Delaware            ', Decimal('4.96')),
#  ('New Hampshire       ', Decimal('4.92')),
#  ('Nebraska            ', Decimal('4.88')),
#  ('Maine               ', Decimal('3.14'))]

# %%
# %%sql
#
# select sentiment, round(avg(duration_minutes),2) as avg_duration
# from calls
# group by sentiment
# order by avg_duration desc
# Out:
#  * postgresql://postgres:***@localhost/call_center_project
# 5 rows affected.
# [('Negative            ', Decimal('25.26')),
#  ('Very Negative       ', Decimal('24.94')),
#  ('Neutral             ', Decimal('24.94')),
#  ('Positive            ', Decimal('24.86')),
#  ('Very Positive       ', Decimal('24.76'))]
